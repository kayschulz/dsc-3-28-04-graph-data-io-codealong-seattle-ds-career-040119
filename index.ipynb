# %% [markdown]
# # NetworkX Introduction - Lab
#
# ## Introduction
#
# In this lab, you'll practice some of the introductory skills for NetworkX introduced in the previous lesson.
# To do this, you'll create a graph to visualize users and businesses from yelp reviews.
# ## Objectives
#
# You will be able to:
# * Create basic network graphs using NetworkX
# * Add nodes to network graphs with NetworkX
# * Add edges to network graphs with NetworkX
# * Visualize network graphs with NetworkX

# %% [markdown]
# ## Import the Data
#
# To start, import the data stored in the file 'Yelp_reviews.csv'

# %%
import pandas as pd
import networkx as nx

# %%
reviews = pd.read_csv('Yelp_reviews.csv')
reviews.head()
# Out:
#               business_id        date               review_id  stars  \
# 0  7SO_rX1F6rQEl-5s3wZxgQ  2011-10-03  GxaYFCprt-wyqO--vB4PHQ      4
# 1  K2_Hmmo5crTYWiT_1sWnfQ  2011-12-22  FSrIgThMfFIh__TubVQkxw      3
# 2  FeI75xIG8PF_XZ6P80gLBQ  2012-06-04  eeJ10gamdNebtq028i0BvA      3
# 3  6imLt53br7SJ3av07jjH7w  2012-11-06  SPDbkT9WXghJedf1xxYnOg      5
# 4  zmFc8M-hS4uuyY0hklIpoQ  2011-01-17  A2lCUSvDJfIa5kwUoFFk8A      4
#
#                                                 text    type  \
# 0  After my last review, somewhat scathing regard...  review
# 1  Ok, so I'm catching up on past-due reviews.  F...  review
# 2  I want to like Turf, but the food is just okay...  review
# 3  It's the place to be. \n\nI went before headin...  review
# 4  A definite favorite in the neighborhood.\n\nTh...  review
#
#                   user_id  cool  useful  funny
# 0  J3I2NClEbD1Xr8lOdjxlqQ     1       2      1
# 1  J3I2NClEbD1Xr8lOdjxlqQ     0       0      0
# 2  64YY0h0ZAR2nbzxbx0IwJg     2       1      0
# 3  Ypz7hxOCnrg8Y8vxHJU-sQ     0       0      0
# 4  nDBly08j5URmrHQ2JCbyiw     2       3      2

# %% [markdown]
# ## Creating a Graph
#
# Now, create an initial graph!

# %%
G = nx.Graph()

# %% [markdown]
# ## Adding Nodes

# %% [markdown]
# Create a node for each user and each business in the dataset. Networks with multiple node types like this are called **bimodal networks**.
#
# Optionally, go further by creating a list of colors for when you visualize the graph. If you do this, append the color "green" to your color list every time you add a user node and append the color "blue" to your color list every time you add a business node.

# %%
businesses = list(reviews['business_id'])
users = list(reviews['user_id'])
colors = []

# %%
for business in businesses:
    G.add_node(business)
    colors.append('green')
    
for user in users:
    G.add_node(user)
    colors.append('blue')

# %% [markdown]
# ## Adding Edges
#
# Next, iterate through the dataset and create an edge between users and the businesses they have reviewed.

# %%
for ind, review in reviews.iterrows():
    print(review)
#     business = review['business_id']
#     user = review['user_id']
#     G.add_edge(business, user)
# Out:
# business_id                               7SO_rX1F6rQEl-5s3wZxgQ
# date                                                  2011-10-03
# review_id                                 GxaYFCprt-wyqO--vB4PHQ
# stars                                                          4
# text           After my last review, somewhat scathing regard...
# type                                                      review
# user_id                                   J3I2NClEbD1Xr8lOdjxlqQ
# cool                                                           1
# useful                                                         2
# funny                                                          1
# Name: 0, dtype: object
# business_id                               K2_Hmmo5crTYWiT_1sWnfQ
# date                                                  2011-12-22
# review_id                                 FSrIgThMfFIh__TubVQkxw
# stars                                                          3
# text           Ok, so I'm catching up on past-due reviews.  F...
# type                                                      review
# user_id                                   J3I2NClEbD1Xr8lOdjxlqQ
# cool                                                           0
# useful                                                         0
# funny                                                          0
# Name: 1, dtype: object
# business_id                               FeI75xIG8PF_XZ6P80gLBQ
# date                                                  2012-06-04
# review_id                                 eeJ10gamdNebtq028i0BvA
# stars                                                          3
# text           I want to like Turf, but the food is just okay...
# type                                                      review
# user_id                                   64YY0h0ZAR2nbzxbx0IwJg
# cool                                                           2
# useful                                                         1
# funny                                                          0
# Name: 2, dtype: object
# business_id                               6imLt53br7SJ3av07jjH7w
# date                                                  2012-11-06
# review_id                                 SPDbkT9WXghJedf1xxYnOg
# stars                                                          5
# text           It's the place to be. \n\nI went before headin...
# type                                                      review
# user_id                                   Ypz7hxOCnrg8Y8vxHJU-sQ
# cool                                                           0
# useful                                                         0
# funny                                                          0
# Name: 3, dtype: object
# business_id                               zmFc8M-hS4uuyY0hklIpoQ
# date                                                  2011-01-17
# review_id                                 A2lCUSvDJfIa5kwUoFFk8A
# stars                                                          4
# text           A definite favorite in the neighborhood.\n\nTh...
# type                                                      review
# user_id                                   nDBly08j5URmrHQ2JCbyiw
# cool                                                           2
# useful                                                         3
# funny                                                          2
# Name: 4, dtype: object
# business_id                               PoRYjYUSjmeWM1WLsx_45w
# date                                                  2012-07-15
# review_id                                 XThJY15-3koNSfynPQTJ_w
# stars                                                          4
# text           The view from the top is quite amazing! I took...
# type                                                      review
# user_id                                   8qSr4B1NJL99rlylewUjOw
# cool                                                           0
# useful                                                         1
# funny                                                          0
# Name: 5, dtype: object
# business_id                               jJhNOhuGpIsJX5SEUFFWYQ
# date                                                  2009-04-11
# review_id                                 t9ngnScZDCF1QTkYKGgEsQ
# stars                                                          4
# text           This is a great staple of Tempe.  I try to sto...
# type                                                      review
# user_id                                   V1k7XMUX4qHVUi-3IUYzhA
# cool                                                           1
# useful                                                         1
# funny                                                          1
# Name: 6, dtype: object
# business_id                               jJhNOhuGpIsJX5SEUFFWYQ
# date                                                  2010-09-12
# review_id                                 eSoWi45YPFQYUz8fN6VdpA
# stars                                                          1
# text           This is my very first review and I can't say I...
# type                                                      review
# user_id                                   w225lKHnX3jorkSXWgss0Q
# cool                                                           0
# useful                                                         1
# funny                                                          0
# Name: 7, dtype: object
# business_id                               jJhNOhuGpIsJX5SEUFFWYQ
# date                                                  2008-08-04
# review_id                                 xTNGA-ZJ8oYS0zA5_dla7g
# stars                                                          3
# text           On my way to the Airport, I decided to stop at...
# type                                                      review
# user_id                                   JffajLV-Dnn-eGYgdXDxFg
# cool                                                           1
# useful                                                         1
# funny                                                          1
# Name: 8, dtype: object
# business_id                               PoRYjYUSjmeWM1WLsx_45w
# date                                                  2012-01-11
# review_id                                 PKzziDJj5KLksknLXhzJWA
# stars                                                          5
# text           I can't add much to what has already been said...
# type                                                      review
# user_id                                   wLuDGMXytNVTF8ZU2gwUEQ
# cool                                                           0
# useful                                                         2
# funny                                                          0
# Name: 9, dtype: object
# business_id                               K2_Hmmo5crTYWiT_1sWnfQ
# date                                                  2011-04-23
# review_id                                 fgEMK0d0upxfalu9JFOYTg
# stars                                                          3
# text           This place is solid...solid...solid...plus its...
# type                                                      review
# user_id                                   X_kPh3nt0AJPNPHye2rTlA
# cool                                                           0
# useful                                                         0
# funny                                                          0
# Name: 10, dtype: object
# business_id                               6imLt53br7SJ3av07jjH7w
# date                                                  2009-05-25
# review_id                                 Ug5Wzg4LNZe9t5qYXE02AQ
# stars                                                          2
# text           Let me say this: the bar at Hanny's is one of ...
# type                                                      review
# user_id                                   xkTbpCc-YhU8-EXZDA7u0g
# cool                                                           2
# useful                                                         2
# funny                                                          0
# Name: 11, dtype: object
# business_id                               4r9-iKOagzn5oUvPE9Bz4Q
# date                                                  2012-09-16
# review_id                                 Apmt0bquoBr47PjWFUx1lA
# stars                                                          4
# text           We get a date night rarely throughout the year...
# type                                                      review
# user_id                                   3SIjo6vQIvxwHKEpIHfaBg
# cool                                                           2
# useful                                                         2
# funny                                                          1
# Name: 12, dtype: object
# business_id                               PoRYjYUSjmeWM1WLsx_45w
# date                                                  2007-10-23
# review_id                                 6b5sifuzXWw0cMd_8c9how
# stars                                                          3
# text           Uh-oh. Where am I? \n\nThe view from atop the ...
# type                                                      review
# user_id                                   APLIPfq1Rf8QyhHHk2uAyA
# cool                                                           4
# useful                                                         5
# funny                                                          4
# Name: 13, dtype: object
# business_id                               7SO_rX1F6rQEl-5s3wZxgQ
# date                                                  2012-12-20
# review_id                                 FqfWt22uSDgca4dRK4PIgw
# stars                                                          5
# text           The best gluten free pizza!! Absolutely loved ...
# type                                                      review
# user_id                                   SW5RpjVtyMhxdzuA8dOdYA
# cool                                                           0
# useful                                                         0
# funny                                                          0
# Name: 14, dtype: object
# business_id                               vSEFzop2GDXsIWTLxIGMiw
# date                                                  2012-02-21
# review_id                                 qfHkekpzM6EVI1mA_yZ1ug
# stars                                                          4
# text           I was hella skeptical that a Phoenix fast food...
# type                                                      review
# user_id                                   -OMlS6yWkYjVldNhC31wYg
# cool                                                           1
# useful                                                         1
# funny                                                          0
# Name: 15, dtype: object
# business_id                               PoRYjYUSjmeWM1WLsx_45w
# date                                                  2012-01-11
# review_id                                 HHASTCkx31YiMeYb8-YMIw
# stars                                                          5
# text           BEAUTIFUL! Phoenix doesn't get much more amazi...
# type                                                      review
# user_id                                   nSLrExcVVphiNzvSf5H7vA
# cool                                                           1
# useful                                                         3
# funny                                                          1
# Name: 16, dtype: object
# business_id                               7SO_rX1F6rQEl-5s3wZxgQ
# date                                                  2008-01-14
# review_id                                 Co24bDyiWK0XStIL8FzZGQ
# stars                                                          4
# text           Given its location and surroundings (Postino's...
# type                                                      review
# user_id                                   -txH2zJSBZQHO6RWvoWXuQ
# cool                                                           3
# useful                                                         1
# funny                                                          1
# Name: 17, dtype: object
# business_id                               7SO_rX1F6rQEl-5s3wZxgQ
# date                                                  2007-03-28
# review_id                                 V8MQK2HLoaFrdj6tfe3Yhw
# stars                                                          3
# text           The Orange is a popular, well-reputed joint in...
# type                                                      review
# user_id                                   yy8vNTtESId44OcGyaVnbw
# cool                                                           0
# useful                                                         2
# funny                                                          3
# Name: 18, dtype: object
# business_id                               jJhNOhuGpIsJX5SEUFFWYQ
# date                                                  2012-12-27
# review_id                                 tPgHu1UT0ZW23vVKuC5y7g
# stars                                                          5
# text           You like hotdogs?  Motor (thats me) says get i...
# type                                                      review
# user_id                                   ehtcnF3Ebvq23p107LcsuA
# cool                                                           1
# useful                                                         1
# funny                                                          1
# Name: 19, dtype: object
# business_id                               L2J3JfjXZLnX1rLhWKthqA
# date                                                  2008-02-05
# review_id                                 vBnGjrTvITilgRQ6_8W16g
# stars                                                          4
# text           There's not much more I can say about Rula tha...
# type                                                      review
# user_id                                   APLIPfq1Rf8QyhHHk2uAyA
# cool                                                           2
# useful                                                         4
# funny                                                          0
# Name: 20, dtype: object
# business_id                               L2J3JfjXZLnX1rLhWKthqA
# date                                                  2010-02-20
# review_id                                 -NZSTwgm1d03JjIDZWq01A
# stars                                                          5
# text           Rula Bula gets five stars from me for two reas...
# type                                                      review
# user_id                                   XMEBJp8mmpz3vsSkvg9T9Q
# cool                                                           2
# useful                                                         2
# funny                                                          2
# Name: 21, dtype: object
# business_id                               zmFc8M-hS4uuyY0hklIpoQ
# date                                                  2012-06-21
# review_id                                 yoD-T4N7qi1YI3PR3wJRDQ
# stars                                                          3
# text           I visited Carly's for a weekday lunch when I w...
# type                                                      review
# user_id                                   tiyg_cQaPdUuSG95Xpi_sA
# cool                                                           0
# useful                                                         0
# funny                                                          0
# Name: 22, dtype: object
# business_id                               PoRYjYUSjmeWM1WLsx_45w
# date                                                  2011-01-10
# review_id                                 0Z8DEk7NkirK1k88GMaerQ
# stars                                                          5
# text           I have been exploring more of the park recentl...
# type                                                      review
# user_id                                   d1zJj49Q5ikgvqQX0534RQ
# cool                                                           1
# useful                                                         1
# funny                                                          0
# Name: 23, dtype: object
# business_id                               FeI75xIG8PF_XZ6P80gLBQ
# date                                                  2009-08-16
# review_id                                 6rN-B5QvWjlGOXMCpjCfxQ
# stars                                                          4
# text           This may be fiction.  I don't know for sure.  ...
# type                                                      review
# user_id                                   vhAn390OgR1H4DwacJdc7w
# cool                                                           8
# useful                                                         7
# funny                                                          9
# Name: 24, dtype: object
# business_id                               7SO_rX1F6rQEl-5s3wZxgQ
# date                                                  2011-08-22
# review_id                                 u86A4P5mPKIQNir48-TUlQ
# stars                                                          4
# text           Oooooh, I liked it, very much so!  Just sad th...
# type                                                      review
# user_id                                   Lmgv46LyI1PlLs0KNIfYFQ
# cool                                                           0
# useful                                                         0
# funny                                                          0
# Name: 25, dtype: object
# business_id                               K2_Hmmo5crTYWiT_1sWnfQ
# date                                                  2011-11-27
# review_id                                 ZTPy5A93V7Ydx6pk1_G3ww
# stars                                                          5
# text           Of all the Chipotle's I really like this one. ...
# type                                                      review
# user_id                                   ryjqXdp68i2I9JPOpX9URw
# cool                                                           0
# useful                                                         0
# funny                                                          0
# Name: 26, dtype: object
# business_id                               7SO_rX1F6rQEl-5s3wZxgQ
# date                                                  2012-09-03
# review_id                                 vkFZfxjmbFfOgbVToyWsBw
# stars                                                          5
# text           Wait a second...I have not written a review!  ...
# type                                                      review
# user_id                                   X_kPh3nt0AJPNPHye2rTlA
# cool                                                           3
# useful                                                         4
# funny                                                          1
# Name: 27, dtype: object
# business_id                               6imLt53br7SJ3av07jjH7w
# date                                                  2009-03-03
# review_id                                 qX7PnzPkPt7Zg8be_sq-hA
# stars                                                          2
# text           I don't know of a single Phoenician who wasn't...
# type                                                      review
# user_id                                   W_QXYA7A0IhMrvbckz7eVg
# cool                                                           2
# useful                                                         4
# funny                                                          2
# Name: 28, dtype: object
# business_id                               Dsvx2LEC8jk9nuGsg1Kqhg
# date                                                  2012-04-19
# review_id                                 HoEbCttQ_69B6xIp85qkcw
# stars                                                          4
# text           Nice, clean store, well-laid out, has all the ...
# type                                                      review
# user_id                                   J3I2NClEbD1Xr8lOdjxlqQ
# cool                                                           0
# useful                                                         2
# funny                                                          1
# Name: 29, dtype: object
# business_id                               vSEFzop2GDXsIWTLxIGMiw
# date                                                  2008-02-27
# review_id                                 8YWzrY18uC2yx3sM-cPqWg
# stars                                                          5
# text           I was initially going to give Riva's 3-stars, ...
# type                                                      review
# user_id                                   clTYUJCL-rHnVIS2WePRwA
# cool                                                           3
# useful                                                         1
# funny                                                          1
# Name: 30, dtype: object
# business_id                               FeI75xIG8PF_XZ6P80gLBQ
# date                                                  2009-03-05
# review_id                                 r8-11K8NPQ3_0BFK1KiAMQ
# stars                                                          3
# text           3.5 if I could, but just a 3 for now.\n\nI rea...
# type                                                      review
# user_id                                   k1ACFw3wmqkNGoiGeNLc0w
# cool                                                           0
# useful                                                         0
# funny                                                          0
# Name: 31, dtype: object
# business_id                               4r9-iKOagzn5oUvPE9Bz4Q
# date                                                  2011-12-07
# review_id                                 ny6Jlfysm6VTYgqmm6l3PA
# stars                                                          5
# text           Fantastic venue! Province really adds a touch ...
# type                                                      review
# user_id                                   nSLrExcVVphiNzvSf5H7vA
# cool                                                           1
# useful                                                         1
# funny                                                          1
# Name: 32, dtype: object
# business_id                               6imLt53br7SJ3av07jjH7w
# date                                                  2008-12-16
# review_id                                 Y7UIAoAOd8BSLIO08jjJZA
# stars                                                          3
# text           I had a hard time even giving this place the t...
# type                                                      review
# user_id                                   fev0iI-XDrteD4SYRKjiUw
# cool                                                           4
# useful                                                         4
# funny                                                          3
# Name: 33, dtype: object
# business_id                               PoRYjYUSjmeWM1WLsx_45w
# date                                                  2010-12-06
# review_id                                 J7GYNwMLHPBff2WT6szLlg
# stars                                                          4
# text           My favorite trail in South Mountain starts at ...
# type                                                      review
# user_id                                   -OMlS6yWkYjVldNhC31wYg
# cool                                                           1
# useful                                                         0
# funny                                                          0
# Name: 34, dtype: object
# business_id                               FeI75xIG8PF_XZ6P80gLBQ
# date                                                  2009-03-09
# review_id                                 kpIyspui9fFLCzDccAxXaw
# stars                                                          4
# text           We tried The Turf for breakfast this weekend. ...
# type                                                      review
# user_id                                   W_QXYA7A0IhMrvbckz7eVg
# cool                                                           1
# useful                                                         1
# funny                                                          1
# Name: 35, dtype: object
# business_id                               6imLt53br7SJ3av07jjH7w
# date                                                  2010-04-21
# review_id                                 6W3KPPnYkYEcIb27CNq-yA
# stars                                                          3
# text           First time here, it's late night and I wanted ...
# type                                                      review
# user_id                                   cg4em4uXe5ab5qH7pB01gg
# cool                                                           0
# useful                                                         1
# funny                                                          0
# Name: 36, dtype: object
# business_id                               zmFc8M-hS4uuyY0hklIpoQ
# date                                                  2010-07-17
# review_id                                 Jy-ufT32E7p_Utvr7Q72YA
# stars                                                          5
# text           I've been here a couple of times.  The first t...
# type                                                      review
# user_id                                   XqU1PB0XWjcr3sUyZZGaWQ
# cool                                                           0
# useful                                                         0
# funny                                                          0
# Name: 37, dtype: object
# business_id                               7SO_rX1F6rQEl-5s3wZxgQ
# date                                                  2011-11-14
# review_id                                 3R2Vfs6v84HIKzvYPKxZ_w
# stars                                                          5
# text           I don't think I've ever been to this place whe...
# type                                                      review
# user_id                                   XLah_ynCwwYshCY9jc13tw
# cool                                                           0
# useful                                                         0
# funny                                                          0
# Name: 38, dtype: object
# business_id                               jJhNOhuGpIsJX5SEUFFWYQ
# date                                                  2008-08-26
# review_id                                 -4ZKS14yOcFjFI8ejPhCXg
# stars                                                          3
# text           Pretty tasty dogs.  Pretty long wait for a hot...
# type                                                      review
# user_id                                   q5nFaw9isjD_01PpVAR7hg
# cool                                                           0
# useful                                                         0
# funny                                                          0
# Name: 39, dtype: object
# business_id                               7SO_rX1F6rQEl-5s3wZxgQ
# date                                                  2011-02-11
# review_id                                 FsgySMO30fkfB589C2M7iA
# stars                                                          5
# text           i cant review restaurants in phx and leave out...
# type                                                      review
# user_id                                   B_leEp0XWSNi5_HQ_BLAAg
# cool                                                           0
# useful                                                         0
# funny                                                          0
# Name: 40, dtype: object
# business_id                               PoRYjYUSjmeWM1WLsx_45w
# date                                                  2009-06-22
# review_id                                 Nlx4nFo54AI9uPVGd3gm8w
# stars                                                          4
# text           The drive to the top is really fun, and the vi...
# type                                                      review
# user_id                                   n_lAaNGeWgspbbCJc0DqRg
# cool                                                           3
# useful                                                         3
# funny                                                          2
# Name: 41, dtype: object
# business_id                               jJhNOhuGpIsJX5SEUFFWYQ
# date                                                  2010-04-24
# review_id                                 A2fpiFbT8HtwwsENElhXDg
# stars                                                          5
# text           AAAAMAZING.\nThey have the best hot dogs and c...
# type                                                      review
# user_id                                   XY_bQqhZfyyEi_W5n4kQNg
# cool                                                           2
# useful                                                         3
# funny                                                          1
# Name: 42, dtype: object
# business_id                               jJhNOhuGpIsJX5SEUFFWYQ
# date                                                  2009-05-05
# review_id                                 uMQ4juin9OVWjvOnLn--NA
# stars                                                          4
# text           Someone asked the question in the Yelp talk th...
# type                                                      review
# user_id                                   ZmIgP4U4Ht9CYmNX0_zP6w
# cool                                                          10
# useful                                                        12
# funny                                                          5
# Name: 43, dtype: object
# business_id                               jJhNOhuGpIsJX5SEUFFWYQ
# date                                                  2008-03-25
# review_id                                 EQu1fQG8Qd9QJ5Jw4-u90A
# stars                                                          5
# text           Ted's rules.  Great char-grilled hot dogs, kil...
# type                                                      review
# user_id                                   clTYUJCL-rHnVIS2WePRwA
# cool                                                           0
# useful                                                         0
# funny                                                          0
# Name: 44, dtype: object
# business_id                               vSEFzop2GDXsIWTLxIGMiw
# date                                                  2009-04-20
# review_id                                 ehB-hp-aOwcpk_9d9M4RTw
# stars                                                          4
# text           I give Riva's 4 stars because of the secret to...
# type                                                      review
# user_id                                   V1k7XMUX4qHVUi-3IUYzhA
# cool                                                           1
# useful                                                         1
# funny                                                          0
# Name: 45, dtype: object
# business_id                               jJhNOhuGpIsJX5SEUFFWYQ
# date                                                  2008-07-17
# review_id                                 1HwtNOm11v0I3QTfSUO8FA
# stars                                                          5
# text           Not many places that you can go and get a natu...
# type                                                      review
# user_id                                   P2vHl_ZzSzeu07W29KsKgg
# cool                                                           2
# useful                                                         2
# funny                                                          1
# Name: 46, dtype: object
# business_id                               7SO_rX1F6rQEl-5s3wZxgQ
# date                                                  2011-12-07
# review_id                                 XMm1bZYrVdoBpjGOd3xMnQ
# stars                                                          5
# text           This place has exceptional food and pretty gre...
# type                                                      review
# user_id                                   3ONPPazUH-Q3XblYJIaA1A
# cool                                                           0
# useful                                                         0
# funny                                                          0
# Name: 47, dtype: object
# business_id                               7SO_rX1F6rQEl-5s3wZxgQ
# date                                                  2011-05-30
# review_id                                 USt-wMQR-rKCpHNr7HOPZw
# stars                                                          5
# text           My friend has raved about this place for month...
# type                                                      review
# user_id                                   NPoOEAPspruMOik-9sKQtQ
# cool                                                           0
# useful                                                         1
# funny                                                          0
# Name: 48, dtype: object
# business_id                               6imLt53br7SJ3av07jjH7w
# date                                                  2009-03-31
# review_id                                 z_25idy29nlCXv5id_nRlw
# stars                                                          3
# text           We went to dinner there on a Sunday and we wer...
# type                                                      review
# user_id                                   sLuaWOJNALukrThYzqovzA
# cool                                                           0
# useful                                                         0
# funny                                                          0
# Name: 49, dtype: object
# business_id                               7SO_rX1F6rQEl-5s3wZxgQ
# date                                                  2010-01-11
# review_id                                 86Ee-P5ePzDj45CNDIlWOw
# stars                                                          5
# text           Really good pizza has to be among the most per...
# type                                                      review
# user_id                                   m59OpbCyRwXSvERXeevWqg
# cool                                                           2
# useful                                                         2
# funny                                                          1
# Name: 50, dtype: object
# business_id                               L2J3JfjXZLnX1rLhWKthqA
# date                                                  2012-01-07
# review_id                                 TIOxXxRDtulXBuqYr1ozPA
# stars                                                          4
# text           Classic Irish Pub on Mill. Perfect for fish an...
# type                                                      review
# user_id                                   nSLrExcVVphiNzvSf5H7vA
# cool                                                           1
# useful                                                         2
# funny                                                          1
# Name: 51, dtype: object
# business_id                               6imLt53br7SJ3av07jjH7w
# date                                                  2009-03-22
# review_id                                 o1_rHrHsCflHCwYv-Ykjfg
# stars                                                          4
# text           What a cool space!  We needed nourishment on S...
# type                                                      review
# user_id                                   o33IBagNFxdJhIrRTl691Q
# cool                                                           1
# useful                                                         1
# funny                                                          1
# Name: 52, dtype: object
# business_id                               6imLt53br7SJ3av07jjH7w
# date                                                  2010-08-30
# review_id                                 0v_0U406ksUc7REYsZ1cPg
# stars                                                          5
# text           Gotta love a place open late in Phoenix. 2.50 ...
# type                                                      review
# user_id                                   hebXGQk5ggZSwTlUoEcTWQ
# cool                                                           0
# useful                                                         1
# funny                                                          0
# Name: 53, dtype: object
# business_id                               zmFc8M-hS4uuyY0hklIpoQ
# date                                                  2010-02-19
# review_id                                 P2BADhNmVrSrZqi-BTvkOQ
# stars                                                          2
# text           I have to admit that I can't stop going to Car...
# type                                                      review
# user_id                                   tdoL4Un5_hy_rJxEFLLOjw
# cool                                                           3
# useful                                                         3
# funny                                                          4
# Name: 54, dtype: object
# business_id                               L2J3JfjXZLnX1rLhWKthqA
# date                                                  2011-04-04
# review_id                                 G_aqfhfRok1lmH4jLCfcZw
# stars                                                          4
# text           As an Irish lass thru and thru, the promise of...
# type                                                      review
# user_id                                   zqnAdayPsak5dbLF2gEvNw
# cool                                                           1
# useful                                                         1
# funny                                                          0
# Name: 55, dtype: object
# business_id                               zmFc8M-hS4uuyY0hklIpoQ
# date                                                  2009-04-18
# review_id                                 5Tnd97z4fKvfvAeYUns4Aw
# stars                                                          3
# text           I don't get the hype, but then again I am not ...
# type                                                      review
# user_id                                   W9h1ufjEzDp7THyAqRw65g
# cool                                                           2
# useful                                                         5
# funny                                                          2
# Name: 56, dtype: object
# business_id                               L2J3JfjXZLnX1rLhWKthqA
# date                                                  2011-01-11
# review_id                                 lvTXEozP5_OzC0UriGGVVQ
# stars                                                          3
# text           The first thing I respect about Rula Bula is i...
# type                                                      review
# user_id                                   jdeNI5TTTuM6mj3HTgstRA
# cool                                                           1
# useful                                                         1
# funny                                                          0
# Name: 57, dtype: object
# business_id                               K2_Hmmo5crTYWiT_1sWnfQ
# date                                                  2012-09-04
# review_id                                 7OTX6no_YKFuZLxDatF0Fg
# stars                                                          5
# text           I have to give them a 5 for their Guacamole an...
# type                                                      review
# user_id                                   oRRHrcRPcEAnOepF3KPfsg
# cool                                                           1
# useful                                                         2
# funny                                                          0
# Name: 58, dtype: object
# business_id                               PoRYjYUSjmeWM1WLsx_45w
# date                                                  2010-02-23
# review_id                                 KqayigmkZK-fD0awCn12Xw
# stars                                                          5
# text           This is the largest urban park. Moreover, that...
# type                                                      review
# user_id                                   M6oU3OBf_E6gqlfkLGlStQ
# cool                                                           1
# useful                                                         3
# funny                                                          1
# Name: 59, dtype: object
# business_id                               7SO_rX1F6rQEl-5s3wZxgQ
# date                                                  2012-04-21
# review_id                                 MdcOO0halc4Z8S4iCUQgVw
# stars                                                          5
# text           Delicious salad, pizza, and wine. We got the P...
# type                                                      review
# user_id                                   bBS2Qsf--DYRXbYe5q4CcQ
# cool                                                           1
# useful                                                         1
# funny                                                          0
# Name: 60, dtype: object
# business_id                               zmFc8M-hS4uuyY0hklIpoQ
# date                                                  2010-10-25
# review_id                                 ZAVp0mqfdr7M9MtAJYfE5Q
# stars                                                          3
# text           I wasn't sure what to expect. This was stop 1 ...
# type                                                      review
# user_id                                   2y3LWFfyRp02EdjwcVv7sw
# cool                                                           0
# useful                                                         1
# funny                                                          0
# Name: 61, dtype: object
# business_id                               PdRzCJWP7nPdYoHPdd5SOQ
# date                                                  2009-02-19
# review_id                                 z5uXQbUqJVwONdETb_qfMw
# stars                                                          3
# text           I didn't have a fully immersed Portland's expe...
# type                                                      review
# user_id                                   o33IBagNFxdJhIrRTl691Q
# cool                                                           2
# useful                                                         1
# funny                                                          2
# Name: 62, dtype: object
# business_id                               FeI75xIG8PF_XZ6P80gLBQ
# date                                                  2009-03-15
# review_id                                 EY9HpLQwcREVtWifjmXtGA
# stars                                                          2
# text           Talk about disappointed.  I had high hopes for...
# type                                                      review
# user_id                                   o33IBagNFxdJhIrRTl691Q
# cool                                                           2
# useful                                                         1
# funny                                                          3
# Name: 63, dtype: object
# business_id                               L2J3JfjXZLnX1rLhWKthqA
# date                                                  2011-04-01
# review_id                                 FPaGbNkeYs2eznETt1T0HA
# stars                                                          1
# text           I'm not sure what all of the buzz is about bec...
# type                                                      review
# user_id                                   O758lrR1X2zI-ySeyjdr6A
# cool                                                           0
# useful                                                         1
# funny                                                          0
# Name: 64, dtype: object
# business_id                               jJhNOhuGpIsJX5SEUFFWYQ
# date                                                  2011-11-04
# review_id                                 6LWNjmEpltmwc8Lo_dw2qw
# stars                                                          5
# text           I can't believe I haven't wrote a review for T...
# type                                                      review
# user_id                                   7o7MF9B9lxcWupE8jiLOaQ
# cool                                                           0
# useful                                                         0
# funny                                                          0
# Name: 65, dtype: object
# business_id                               7SO_rX1F6rQEl-5s3wZxgQ
# date                                                  2010-03-08
# review_id                                 o1jc-nqCqeZ6Iq3AIve69g
# stars                                                          4
# text           I feel like an East Coast gangster when I roll...
# type                                                      review
# user_id                                   OksbhhgC71Ary3zNHMypeQ
# cool                                                           2
# useful                                                         2
# funny                                                          0
# Name: 66, dtype: object
# business_id                               jJhNOhuGpIsJX5SEUFFWYQ
# date                                                  2011-04-27
# review_id                                 raCtfWSWifX6KmuPGSu1yg
# stars                                                          5
# text           Imagine for a minute that you're waiting in a ...
# type                                                      review
# user_id                                   7zDqr2I0-xpw9HF5Ha54cA
# cool                                                           1
# useful                                                         3
# funny                                                          2
# Name: 67, dtype: object
# business_id                               7SO_rX1F6rQEl-5s3wZxgQ
# date                                                  2012-10-08
# review_id                                 BZOu01JHq8EdZtPz6j3sqQ
# stars                                                          5
# text           I'm going to be an uptight stickler here, and ...
# type                                                      review
# user_id                                   o2CGc1kQHEFkYOECM3NFdg
# cool                                                           0
# useful                                                         0
# funny                                                          0
# Name: 68, dtype: object
# business_id                               zmFc8M-hS4uuyY0hklIpoQ
# date                                                  2009-01-27
# review_id                                 tmd_ihdNuq7NqF0uzahX8w
# stars                                                          4
# text           Carly's is a cute little restaurant with a fun...
# type                                                      review
# user_id                                   ai2W745a8wrLHJr7TY0FCA
# cool                                                           2
# useful                                                         1
# funny                                                          1
# Name: 69, dtype: object
# business_id                               zmFc8M-hS4uuyY0hklIpoQ
# date                                                  2010-03-04
# review_id                                 DnLwKwS88h6zqUdqHflczQ
# stars                                                          4
# text           Carly's Bistro is one of my new favorites - es...
# type                                                      review
# user_id                                   kq5Pdsy8Znyh9KEkxWT_QA
# cool                                                           2
# useful                                                         2
# funny                                                          0
# Name: 70, dtype: object
# business_id                               Dsvx2LEC8jk9nuGsg1Kqhg
# date                                                  2009-09-04
# review_id                                 3NeeZn65Gi-l6qeJWlrblQ
# stars                                                          4
# text           Before I shop at Whole Foods (which is on the ...
# type                                                      review
# user_id                                   Cj6tGJrLEdN35H9cR6b8Lw
# cool                                                           0
# useful                                                         1
# funny                                                          0
# Name: 71, dtype: object
# business_id                       Dsvx2LEC8jk9nuGsg1Kqhg
# date                                          2012-10-29
# review_id                         5sxHw2-iHV7TGtGqAhuPwA
# stars                                                  3
# text           Great place to grab some quick groceries.
# type                                              review
# user_id                           wDAAn0HlnuZQnfga6CVIKQ
# cool                                                   0
# useful                                                 0
# funny                                                  0
# Name: 72, dtype: object
# business_id                               zmFc8M-hS4uuyY0hklIpoQ
# date                                                  2009-02-19
# review_id                                 kWilrefFxn6DLRqyT8-uPA
# stars                                                          5
# text           Mmm dirty hipster bars.  Let me count the ways...
# type                                                      review
# user_id                                   o33IBagNFxdJhIrRTl691Q
# cool                                                           4
# useful                                                         5
# funny                                                          8
# Name: 73, dtype: object
# business_id                               jJhNOhuGpIsJX5SEUFFWYQ
# date                                                  2009-07-30
# review_id                                 ycAsRoIHFGdnU98ii2Imew
# stars                                                          2
# text           In Short: Long lines, complicated menu, and a ...
# type                                                      review
# user_id                                   n4PmRYAvx2c6X0-fb9mT9Q
# cool                                                           2
# useful                                                         2
# funny                                                          1
# Name: 74, dtype: object
# business_id                               vSEFzop2GDXsIWTLxIGMiw
# date                                                  2010-08-06
# review_id                                 we5T3NsdF_oPrbPBpMo31w
# stars                                                          5
# text           Rivas helped me get through numerous late nigh...
# type                                                      review
# user_id                                   2tyadgcxcaEu5LWgLdwLAQ
# cool                                                           0
# useful                                                         0
# funny                                                          0
# Name: 75, dtype: object

# %% [markdown]
# ## Visualizing the Graph
#
# Finally, create a visualization of your network. If you chose to color your nodes, pass the list of colors through the optional `node_color` parameter.

# %%
#Your code here

# %% [markdown]
# ## Summary
#
# Nice work! In this lab you created an initial network to visualize a bimodal network of businesses and yelp reviewers!
